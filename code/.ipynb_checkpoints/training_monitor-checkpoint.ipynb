# %%
import ast
import json
import pandas as pd

# %%
filename = "results/dt_shuttle_uniformly.json" 
with open(filename) as fp:
    data = fp.read()
    
d1 = ast.literal_eval(data)
print(d1)
# Out:
# {'2.0': {'344': {'total': 66, 'tp': 66}, '0': {'total': 66, 'tp': 18}, '346': {'total': 66, 'tp': 66}, '347': {'total': 66, 'tp': 66}, '340': {'total': 66, 'tp': 66}, '341': {'total': 66, 'tp': 66}, '342': {'total': 66, 'tp': 66}, '343': {'total': 66, 'tp': 66}, '810': {'total': 66, 'tp': 66}, '811': {'total': 66, 'tp': 66}, '812': {'total': 66, 'tp': 66}, '813': {'total': 66, 'tp': 66}, '348': {'total': 66, 'tp': 66}, '349': {'total': 66, 'tp': 66}, '816': {'total': 66, 'tp': 66}, '817': {'total': 66, 'tp': 66}, '595': {'total': 66, 'tp': 66}, '719': {'total': 66, 'tp': 66}, '718': {'total': 66, 'tp': 66}, '717': {'total': 66, 'tp': 66}, '716': {'total': 66, 'tp': 66}, '715': {'total': 66, 'tp': 66}, '714': {'total': 66, 'tp': 66}, '713': {'total': 66, 'tp': 66}, '712': {'total': 66, 'tp': 66}, '711': {'total': 66, 'tp': 66}, '710': {'total': 66, 'tp': 66}, '915': {'total': 66, 'tp': 66}, '914': {'total': 66, 'tp': 66}, '606': {'total': 66, 'tp': 66}, '917': {'total': 66, 'tp': 66}, '594': {'total': 66, 'tp': 66}, '736': {'total': 66, 'tp': 66}, '916': {'total': 66, 'tp': 66}, '911': {'total': 66, 'tp': 66}, '619': {'total': 66, 'tp': 66}, '910': {'total': 66, 'tp': 66}, '913': {'total': 66, 'tp': 66}, '298': {'total': 66, 'tp': 66}, '299': {'total': 66, 'tp': 66}, '296': {'total': 66, 'tp': 66}, '297': {'total': 66, 'tp': 66}, '294': {'total': 66, 'tp': 66}, '295': {'total': 66, 'tp': 66}, '292': {'total': 66, 'tp': 66}, '293': {'total': 66, 'tp': 66}, '290': {'total': 66, 'tp': 66}, '291': {'total': 66, 'tp': 66}, '591': {'total': 66, 'tp': 66}, '590': {'total': 66, 'tp': 66}, '593': {'total': 66, 'tp': 66}, '592': {'total': 66, 'tp': 66}, '199': {'total': 66, 'tp': 66}, '198': {'total': 66, 'tp': 66}, '597': {'total': 66, 'tp': 66}, '596': {'total': 66, 'tp': 66}, '195': {'total': 66, 'tp': 66}, '194': {'total': 66, 'tp': 66}, '197': {'total': 66, 'tp': 66}, '196': {'total': 66, 'tp': 66}, '191': {'total': 66, 'tp': 66}, '190': {'total': 66, 'tp': 66}, '193': {'total': 66, 'tp': 66}, '192': {'total': 66, 'tp': 66}, '270': {'total': 66, 'tp': 66}, '271': {'total': 66, 'tp': 66}, '272': {'total': 66, 'tp': 66}, '273': {'total': 66, 'tp': 66}, '274': {'total': 66, 'tp': 66}, '275': {'total': 66, 'tp': 66}, '276': {'total': 66, 'tp': 66}, '277': {'total': 66, 'tp': 66}, '278': {'total': 66, 'tp': 66}, '279': {'total': 66, 'tp': 66}, '738': {'total': 66, 'tp': 66}, '524': {'total': 66, 'tp': 66}, '525': {'total': 66, 'tp': 66}, '526': {'total': 66, 'tp': 66}, '527': {'total': 66, 'tp': 66}, '520': {'total': 66, 'tp': 66}, '521': {'total': 66, 'tp': 66}, '522': {'total': 66, 'tp': 66}, '523': {'total': 66, 'tp': 66}, '599': {'total': 66, 'tp': 66}, '528': {'total': 66, 'tp': 66}, '529': {'total': 66, 'tp': 66}, '994': {'total': 66, 'tp': 66}, '449': {'total': 66, 'tp': 66}, '448': {'total': 66, 'tp': 66}, '443': {'total': 66, 'tp': 66}, '442': {'total': 66, 'tp': 66}, '441': {'total': 66, 'tp': 66}, '440': {'total': 66, 'tp': 66}, '447': {'total': 66, 'tp': 66}, '446': {'total': 66, 'tp': 66}, '445': {'total': 66, 'tp': 66}, '444': {'total': 66, 'tp': 66}, '108': {'total': 66, 'tp': 66}, '109': {'total': 66, 'tp': 66}, '102': {'total': 66, 'tp': 66}, '103': {'total': 66, 'tp': 66}, '100': {'total': 66, 'tp': 66}, '101': {'total': 66, 'tp': 66}, '106': {'total': 66, 'tp': 66}, '107': {'total': 66, 'tp': 66}, '104': {'total': 66, 'tp': 66}, '105': {'total': 66, 'tp': 66}, '902': {'total': 66, 'tp': 66}, '903': {'total': 66, 'tp': 66}, '39': {'total': 66, 'tp': 46}, '38': {'total': 66, 'tp': 46}, '906': {'total': 66, 'tp': 66}, '907': {'total': 66, 'tp': 66}, '904': {'total': 66, 'tp': 66}, '905': {'total': 66, 'tp': 66}, '33': {'total': 66, 'tp': 38}, '32': {'total': 66, 'tp': 38}, '31': {'total': 66, 'tp': 38}, '30': {'total': 66, 'tp': 38}, '37': {'total': 66, 'tp': 46}, '36': {'total': 66, 'tp': 46}, '35': {'total': 66, 'tp': 46}, '34': {'total': 66, 'tp': 40}, '641': {'total': 66, 'tp': 66}, '640': {'total': 66, 'tp': 66}, '64 ...

# %%
labels = []
gens = []
accs = []

for label,v in d1.items():
    for gen, v1 in d1[label].items():
        if (int(gen)+1)%50 == 0:
            total = d1[label][gen].get("total")
            tp = d1[label][gen].get("tp")
            if not tp:
                tp = 0
            acc = round(float(tp)/float(total), 4)
            labels.append(label)
            gens.append(int(gen)+1)
            accs.append(acc)

df = pd.DataFrame({"Label": labels, "Generations": gens, "Classification Accuracy": accs})

# %%
df = df.sort_values(by=['Label', 'Generations'])
df.head()
# Out:
#     Classification Accuracy  Generations Label
# 39                   0.7879           50   1.0
# 25                   0.9091          100   1.0
# 26                   0.9242          150   1.0
# 22                   1.0000          200   1.0
# 29                   1.0000          250   1.0

# %%
df = df.pivot(index='Generations', columns='Label', values='Classification Accuracy')
df.plot()
plt.savefig(filename.rstrip(".json")+'.png', dpi=300)
plt.show()

# %%
import seaborn as sns

ax = sns.lineplot(x="Generations", y="Training Accuracy", data=label1_df)
ax.set(xlabel='Generations', ylabel='Training Accuracy')
# save_plot("event_detection_time_by_varying_time_slice_duration", plt)
plt.show()
# Out:
# -------------------------------------------------------------------------
# AttributeError                          Traceback (most recent call last)
# <ipython-input-36-c6b0b1844aa1> in <module>()
#       1 import seaborn as sns
#       2
# ----> 3 ax = sns.lineplot(x="Generations", y="Training Accuracy", data=label1_df)
#       4 ax.set(xlabel='Generations', ylabel='Training Accuracy')
#       5 # save_plot("event_detection_time_by_varying_time_slice_duration", plt)
#
# AttributeError: 'module' object has no attribute 'lineplot'
